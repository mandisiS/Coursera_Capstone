# %% [markdown]
# ## The battle of neighborhoods:  What top three business types can  an investor invest in or can someone consider to open in neighborhoods of Bronx and Queens (New York boroughs).

# %% [markdown]
# ### 2. Data section: describing the data to be used

# %% [markdown]
# #### 2.1 Data sources

# %% [markdown]
# The dataset that will be used is the New York dataset from the New York University, Data link is https://geo.nyu.edu/catalog/nyu_2451_34572.
# The data essentially contains five boroughs and the neighborhoods data that exist in each borough as well as the the latitude and longitude (spatial data) coordinates of each neighborhood. The Boroughs that will be analysed/of interest for the problem statement are Bronx and Queens and their respective neighborhoods.
#
#
# Newyork City spatial coordinates data will be used as input through the Foursquare API,that will be leveraged to provision venues information for each neighborhood. Foursquare API will be used to explore neighborhoods in New York City. Foursquare API credentials are required when exploring the venues.
#
#
# The typical final data layout when the retrieved Foursquare location data of the venues is merged with the neighborhood spatial data is as follows,where the neighborhoods of Manhatten are shown in this case for illustration purposes.
#
# ![image.png](attachment:image.png)
#
# Data analysis from such table above will help generate results for the required outcome.
